# %%
import numpy as np
import matplotlib.pyplot as plt
import PIL
from PIL import Image
from PIL import ImageFont
from PIL import ImageDraw
from PIL import ImageChops

# %%
new_img = Image.open(r"C:\Users\mahalakshmi\Downloads\meme_5.jpg")
plt.imshow(new_img)

# %%
new_img = Image.open(r"C:\Users\mahalakshmi\Downloads\meme_5.jpg")
font1 = ImageFont.truetype(r"C:\Users\mahalakshmi\Downloads\CrimsonText-Regular.ttf",70)
draw = ImageDraw.Draw(new_img)
draw.text((610,200), "*o t h e r  c o u r s e",font=font1, \
          fill=(0,0,0), stroke_width=1)
draw.text((610,700), "*d a t a s c i e n c e",font=font1, \
          fill=(0,0,0), stroke_width=1)
plt.imshow(new_img)

# %%
new_img = Image.open(r"C:\Users\mahalakshmi\Downloads\meme_1.PNG")
plt.imshow(new_img)

# %%
font1 = ImageFont.truetype(r"C:\Users\mahalakshmi\Downloads\CrimsonText-Regular.ttf",50)
draw = ImageDraw.Draw(new_img)
draw.text((900,200), "*o t h e r  c o u r s e",font=font1, \
          fill=(0,0,0), stroke_width=1)
draw.text((300,200), "*d a t a s c i e n c e",font=font1, \
          fill=(0,0,0), stroke_width=1)
plt.imshow(new_img)

# %%
new_img = Image.open(r"C:\Users\mahalakshmi\Downloads\meme_3.jpg")
plt.imshow(new_img)

# %%
font1 = ImageFont.truetype(r"C:\Users\mahalakshmi\Downloads\CrimsonText-Regular.ttf",50)
draw = ImageDraw.Draw(new_img)
draw.text((200,700), "*when you miss the task deadline",font=font1, \
          fill=(0,0,0), stroke_width=1)
plt.imshow(new_img)

# %%
new_img = Image.open(r"C:\Users\mahalakshmi\Downloads\meme_4.png")
plt.imshow(new_img)

# %%
font1 = ImageFont.truetype(r"C:\Users\mahalakshmi\Downloads\CrimsonText-Regular.ttf",50)
draw = ImageDraw.Draw(new_img)
draw.text((200,200), "*what if AI replaces Data Analysts",font=font1, \
          fill=(0,0,0), stroke_width=1)
plt.imshow(new_img)

# %%
new_img = Image.open(r"C:\Users\mahalakshmi\Downloads\meme_6.png")
plt.imshow(new_img)

# %%
font1 = ImageFont.truetype(r"C:\Users\mahalakshmi\Downloads\CrimsonText-Regular.ttf",20)
draw = ImageDraw.Draw(new_img)
draw.text((10,50), "ML Day 1",font=font1, \
          fill=(0,0,0), stroke_width=1)
draw.text((10,175), "DL Day 1",font=font1, \
          fill=(0,0,0), stroke_width=1)
plt.imshow(new_img)
